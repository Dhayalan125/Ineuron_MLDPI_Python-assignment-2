# %%
#Nested for loop in Python
n=5;
for i in range(n):
    for j in range(i):
        print ('* ', end="")
    print('')

for i in range(n,0,-1):
    for j in range(i):
        print('* ', end="")
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
user_input = input("Input word: ")

x = user_input[::-1]
print("Output: ", x)
# Out:
# Input word:  Dhaya
# Output:  ayahD
